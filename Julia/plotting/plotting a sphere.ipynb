# %%
using Pkg
Pkg.activate(".")
using Plots
pyplot() # select the PyPlot backend
;

# %% [markdown]
# This time I'm not using the default GR backend, but the PyPlot backend.  PyPlot is a wrapper for the Python library Matplotlib (very big, very fancy).

# %%
include("Sphere.jl")
# Out:
# Main.Sphere

# %%
x,y,z = Sphere.sphere(20);

# %%
surface(x,y,z, 
aspect_ratio = :equal,
xlabel = "x", ylabel="y", zlabel = "z")

# %%
xc, yc, zc = 0,0,0
xr, yr, zr = 1,0.5,3
x,y,z = Sphere.ellipsoid( xc, yc, zc, xr, yr, zr )

surface(x,y,z, 
    aspect_ratio = :equal,
    xlabel = "x", ylabel="y", zlabel = "z")
# I'm unsure of how to fix the aspect ratio in z.  It doesn't seem to work
